# %%
import requests
from lxml import etree
import json
import openpyxl


url = 'https://voice.baidu.com/act/newpneumonia/newpneumonia'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
response = requests.get(url=url, headers=headers).text

html = etree.HTML(response)

json_text = html.xpath('//script[@type="application/json"]/text()')

json_text = json_text[0]

b = json.dumps(json_text)
f2 = open('new_json.json', 'w')
f2.write(b)
f2.close()

# result = json.loads(json_text)
# print(result)
# result = result["component"]
# result = result[0]['caseList']

'''
wb = openpyxl.Workbook()
ws = wb.active
ws.title = "国内疫情"
ws.append(["省份", "确诊", "死亡", "治愈"])


for line in result:
    line_name = [line["area"], line["confirmed"], line["died"], line["crued"]]
    for ele in line_name:
        if ele == '':
            ele = 0
    ws.append(line_name)

    # print(line_name)

wb.save('C:/Users/86183/Desktop/china.xlsx')

#可视化
import pandas as pd
from pyecharts.charts import Map,Page
from pyecharts import options as opts

pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

df = pd.read_excel('C:/Users/86183/Desktop/china.xlsx')

data2 = df['省份']
data2_list = list(data2)
data3 = df['确诊']
data3_list = list(data3)
data4 = df['死亡']
data4_list = list(data4)
data5 = df ['治愈']
data5_list = list(data5)

c = (
    Map()
    .add("确诊", [list(z) for z in zip(data2_list, data5_list)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(),
        visualmap_opts=opts.VisualMapOpts(max_=200),
                    )
    )

c.render()
'''
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:667, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=665'>666</a> if is_new_proxy_conn:
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=666'>667</a>     self._prepare_proxy(conn)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=668'>669</a> # Make the request on the httplib connection object.
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:932, in HTTPSConnectionPool._prepare_proxy(self, conn)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=930'>931</a> conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=931'>932</a> conn.connect()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py:317, in HTTPSConnection.connect(self)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connection.py?line=314'>315</a> # Calls self._set_hostport(), so self.host is
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connection.py?line=315'>316</a> # self._tunnel_host below.
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connection.py?line=316'>317</a> self._tunnel()
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connection.py?line=317'>318</a> # Mark this connection as not reusable
#
# File C:\Program Files\Python38\lib\http\client.py:894, in HTTPConnection._tunnel(self)
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=892'>893</a> response = self.response_class(self.sock, method=self._method)
# --> <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=893'>894</a> (version, code, message) = response._read_status()
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=895'>896</a> if code != http.HTTPStatus.OK:
#
# File C:\Program Files\Python38\lib\http\client.py:272, in HTTPResponse._read_status(self)
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=268'>269</a> if not line:
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=269'>270</a>     # Presumably, the server closed the connection before
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=270'>271</a>     # sending a valid response.
# --> <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=271'>272</a>     raise RemoteDisconnected("Remote end closed connection without"
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=272'>273</a>                              " response")
#     <a href='file:///c%3A/Program%20Files/Python38/lib/http/client.py?line=273'>274</a> try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=437'>438</a> if not chunked:
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=438'>439</a>     resp = conn.urlopen(
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=439'>440</a>         method=request.method,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=440'>441</a>         url=url,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=441'>442</a>         body=request.body,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=442'>443</a>         headers=request.headers,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=443'>444</a>         redirect=False,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=444'>445</a>         assert_same_host=False,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=445'>446</a>         preload_content=False,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=446'>447</a>         decode_content=False,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=447'>448</a>         retries=self.max_retries,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=448'>449</a>         timeout=timeout
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=449'>450</a>     )
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=451'>452</a> # Send the request.
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=452'>453</a> else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:726, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=723'>724</a>     e = ProtocolError("Connection aborted.", e)
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=725'>726</a> retries = retries.increment(
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=726'>727</a>     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=727'>728</a> )
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/connectionpool.py?line=728'>729</a> retries.sleep()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\retry.py:446, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/util/retry.py?line=444'>445</a> if new_retry.is_exhausted():
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/util/retry.py?line=445'>446</a>     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/urllib3/util/retry.py?line=447'>448</a> log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='voice.baidu.com', port=443): Max retries exceeded with url: /act/newpneumonia/newpneumonia (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# c:\Users\86183\Desktop\public_ sentiment\Corona-visual\baidu.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=6'>7</a> url = 'https://voice.baidu.com/act/newpneumonia/newpneumonia'
#       <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=7'>8</a> headers = {
#       <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=8'>9</a>     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
# ---> <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=9'>10</a> response = requests.get(url=url, headers=headers).text
#      <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=11'>12</a> html = etree.HTML(response)
#      <a href='vscode-notebook-cell:/c%3A/Users/86183/Desktop/public_%20sentiment/Corona-visual/baidu.ipynb#ch0000000?line=13'>14</a> json_text = html.xpath('//script[@type="application/json"]/text()')
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:76, in get(url, params, **kwargs)
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=64'>65</a> r"""Sends a GET request.
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=65'>66</a>
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=66'>67</a> :param url: URL for the new :class:`Request` object.
#    (...)
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=71'>72</a> :rtype: requests.Response
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=72'>73</a> """
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=74'>75</a> kwargs.setdefault('allow_redirects', True)
# ---> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=75'>76</a> return request('get', url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=56'>57</a> # By using the 'with' statement we are sure the session is closed, thus we
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=57'>58</a> # avoid leaving sockets open which can trigger a ResourceWarning in some
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=58'>59</a> # cases, and look like a memory leak in others.
#      <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=59'>60</a> with sessions.Session() as session:
# ---> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/api.py?line=60'>61</a>     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:530, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=524'>525</a> send_kwargs = {
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=525'>526</a>     'timeout': timeout,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=526'>527</a>     'allow_redirects': allow_redirects,
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=527'>528</a> }
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=528'>529</a> send_kwargs.update(settings)
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=529'>530</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=531'>532</a> return resp
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:643, in Session.send(self, request, **kwargs)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=639'>640</a> start = preferred_clock()
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=641'>642</a> # Send the request
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=642'>643</a> r = adapter.send(request, **kwargs)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=644'>645</a> # Total elapsed time of the request (approximately)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/sessions.py?line=645'>646</a> elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=506'>507</a>     raise RetryError(e, request=request)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=508'>509</a> if isinstance(e.reason, _ProxyError):
# --> <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=509'>510</a>     raise ProxyError(e, request=request)
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=511'>512</a> if isinstance(e.reason, _SSLError):
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=512'>513</a>     # This branch is for urllib3 v1.22 and later.
#     <a href='file:///c%3A/Users/86183/AppData/Roaming/Python/Python38/site-packages/requests/adapters.py?line=513'>514</a>     raise SSLError(e, request=request)
#
# ProxyError: HTTPSConnectionPool(host='voice.baidu.com', port=443): Max retries exceeded with url: /act/newpneumonia/newpneumonia (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
